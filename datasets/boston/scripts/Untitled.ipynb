# %%
import pandas as pd
import numpy as np
import datetime
import os

import xgboost as xgb
from tensorboardX import SummaryWriter

#from sklearn.datasets import load_boston
from sklearn.model_selection import train_test_split

class TensorBoardCallback(xgb.callback.TrainingCallback):
    def __init__(self, experiment: str = None, data_name: str = None):
        self.experiment = experiment or "logs"
        self.data_name = data_name or "test"
        self.datetime_ = datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
        self.log_dir = f"runs/{self.experiment}/{self.datetime_}"
        self.train_writer = SummaryWriter(log_dir=os.path.join(self.log_dir, "train/"))
        if self.data_name:
            self.test_writer = SummaryWriter(
                log_dir=os.path.join(self.log_dir, f"{self.data_name}/")
            )

    def after_iteration(
        self, model, epoch: int, evals_log: xgb.callback.TrainingCallback.EvalsLog
    ) -> bool:
        if not evals_log:
            return False

        for data, metric in evals_log.items():
            for metric_name, log in metric.items():
                score = log[-1][0] if isinstance(log[-1], tuple) else log[-1]
                if data == "train":
                    self.train_writer.add_scalar(metric_name, score, epoch)
                else:
                    self.test_writer.add_scalar(metric_name, score, epoch)

        return False

# %%
data_url = "http://lib.stat.cmu.edu/datasets/boston"
raw_df = pd.read_csv(data_url, sep=r"\s+", skiprows=22, header=None)
data = np.hstack([raw_df.values[::2, :], raw_df.values[1::2, :2]])
target = raw_df.values[1::2, 2]

# %%
data
# Out:
# array([[6.3200e-03, 1.8000e+01, 2.3100e+00, ..., 1.5300e+01, 3.9690e+02,
#         4.9800e+00],
#        [2.7310e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9690e+02,
#         9.1400e+00],
#        [2.7290e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9283e+02,
#         4.0300e+00],
#        ...,
#        [6.0760e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#         5.6400e+00],
#        [1.0959e-01, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9345e+02,
#         6.4800e+00],
#        [4.7410e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#         7.8800e+00]])

# %%
X_train, X_test, y_train, y_test = train_test_split(data, target, test_size=0.2, random_state=100)

dtrain = xgb.DMatrix(X_train, label=y_train)
dtest = xgb.DMatrix(X_test, label=y_test)

params = {'objective':'reg:squarederror', 'eval_metric': 'rmse'}

# %%
params = {'objective':'reg:squarederror', 'eval_metric': 'rmse'}

bst = xgb.train(params, dtrain, num_boost_round=100, evals=[(dtrain, 'train'), (dtest, 'test')],
        callbacks=[TensorBoardCallback(experiment='exp_1', data_name='test')])
# Out:
# [0]	train-rmse:6.72100	test-rmse:7.46559
# [1]	train-rmse:5.06958	test-rmse:5.82633
# [2]	train-rmse:3.90621	test-rmse:4.85099
# [3]	train-rmse:3.07580	test-rmse:4.21755
# [4]	train-rmse:2.47553	test-rmse:3.73335
# [5]	train-rmse:2.02599	test-rmse:3.50519
# [6]	train-rmse:1.68859	test-rmse:3.39425
# [7]	train-rmse:1.45239	test-rmse:3.28750
# [8]	train-rmse:1.28438	test-rmse:3.22570
# [9]	train-rmse:1.16120	test-rmse:3.21039
# [10]	train-rmse:1.05986	test-rmse:3.17595
# [11]	train-rmse:0.95726	test-rmse:3.16765
# [12]	train-rmse:0.88131	test-rmse:3.14554
# [13]	train-rmse:0.81894	test-rmse:3.13116
# [14]	train-rmse:0.77485	test-rmse:3.13649
# [15]	train-rmse:0.72495	test-rmse:3.11582
# [16]	train-rmse:0.69172	test-rmse:3.11919
# [17]	train-rmse:0.66702	test-rmse:3.10890
# [18]	train-rmse:0.62824	test-rmse:3.11224
# [19]	train-rmse:0.57492	test-rmse:3.11683
# [20]	train-rmse:0.54343	test-rmse:3.12190
# [21]	train-rmse:0.51630	test-rmse:3.11994
# [22]	train-rmse:0.48323	test-rmse:3.11870
# [23]	train-rmse:0.44460	test-rmse:3.11712
# [24]	train-rmse:0.42343	test-rmse:3.11859
# [25]	train-rmse:0.41583	test-rmse:3.11813
# [26]	train-rmse:0.40449	test-rmse:3.12041
# [27]	train-rmse:0.39677	test-rmse:3.11800
# [28]	train-rmse:0.36931	test-rmse:3.11904
# [29]	train-rmse:0.35432	test-rmse:3.11868
# [30]	train-rmse:0.33116	test-rmse:3.11134
# [31]	train-rmse:0.31495	test-rmse:3.11768
# [32]	train-rmse:0.30607	test-rmse:3.11770
# [33]	train-rmse:0.29699	test-rmse:3.11934
# [34]	train-rmse:0.27709	test-rmse:3.11940
# [35]	train-rmse:0.27183	test-rmse:3.11933
# [36]	train-rmse:0.25737	test-rmse:3.11893
# [37]	train-rmse:0.24689	test-rmse:3.11564
# [38]	train-rmse:0.23044	test-rmse:3.11292
# [39]	train-rmse:0.21807	test-rmse:3.11488
# [40]	train-rmse:0.20672	test-rmse:3.11287
# [41]	train-rmse:0.20067	test-rmse:3.10964
# [42]	train-rmse:0.19804	test-rmse:3.10888
# [43]	train-rmse:0.18849	test-rmse:3.10751
# [44]	train-rmse:0.17461	test-rmse:3.10919
# [45]	train-rmse:0.15910	test-rmse:3.10970
# [46]	train-rmse:0.15554	test-rmse:3.10993
# [47]	train-rmse:0.14598	test-rmse:3.11006
# [48]	train-rmse:0.13813	test-rmse:3.10798
# [49]	train-rmse:0.12724	test-rmse:3.10882
# [50]	train-rmse:0.11952	test-rmse:3.10815
# [51]	train-rmse:0.11108	test-rmse:3.10822
# [52]	train-rmse:0.10778	test-rmse:3.10854
# [53]	train-rmse:0.10150	test-rmse:3.10950
# [54]	train-rmse:0.09893	test-rmse:3.10958
# [55]	train-rmse:0.09672	test-rmse:3.10869
# [56]	train-rmse:0.09506	test-rmse:3.11005
# [57]	train-rmse:0.08836	test-rmse:3.10945
# [58]	train-rmse:0.08423	test-rmse:3.10795
# [59]	train-rmse:0.08165	test-rmse:3.10913
# [60]	train-rmse:0.07880	test-rmse:3.10962
# [61]	train-rmse:0.07516	test-rmse:3.10952
# [62]	train-rmse:0.07219	test-rmse:3.10990
# [63]	train-rmse:0.06982	test-rmse:3.11012
# [64]	train-rmse:0.06870	test-rmse:3.10990
# [65]	train-rmse:0.06545	test-rmse:3.11006
# [66]	train-rmse:0.06234	test-rmse:3.10936
# [67]	train-rmse:0.05987	test-rmse:3.10954
# [68]	train-rmse:0.05553	test-rmse:3.10898
# [69]	train-rmse:0.05294	test-rmse:3.10838
# [70]	train-rmse:0.05026	test-rmse:3.10694
# [71]	train-rmse:0.04881	test-rmse:3.10697
# [72]	train-rmse:0.04667	test-rmse:3.10682
# [73]	train-rmse:0.04510	test-rmse:3.10738
# [74]	train-rmse:0.04333	test-rmse:3.10741
# [75]	train-rmse:0.04181	test-rmse:3.10728
# [76]	train-rmse:0.04018	test-rmse:3.10761
# [77]	train-rmse:0.03809	test-rmse:3.10724
# [78]	train-rmse:0.03727	test-rmse:3.10770
# [79]	train-rmse:0.03643	test-rmse:3.10734
# [80]	train-rmse:0.03539	test-rmse:3.10777
# [81]	train-rmse:0.03440	test-rmse:3.10787
# [82]	train-rmse:0.03294	test-rmse:3.10818
# [83]	train-rmse:0.03219	test-rmse:3.10791
# [84]	train-rmse:0.03082	test-rmse:3.10729
# [85]	train-rmse:0.02929	test-rmse:3.10686
# [86]	train-rmse:0.02796	test-rmse:3.10697
# [87]	train-rmse:0.02611	test-rmse:3.10727
# [88]	train-rmse:0.02577	test-rmse:3.10753
# [89]	train-rmse:0.02510	test-rmse:3.10768
# [90]	train-rmse:0.02409	test-rmse:3.10791
# [91]	train-rmse:0.02282	test-rmse:3.10794
# [92]	train-rmse:0.02221	test-rmse:3.10811
# [93]	train-rmse:0.02071	test-rmse:3.10778
# [94]	train-rmse:0.01950	test-rmse:3.10802
# [95]	train-rmse:0.01819	test-rmse:3.10779
# [96]	train-rmse:0.01768	test-rmse:3.10755
# [97]	train-rmse:0.01626	test-rmse:3.10781
# [98]	train-rmse:0.01599	test-rmse:3.10770
# [99]	train-rmse:0.01578	test-rmse:3.10790
